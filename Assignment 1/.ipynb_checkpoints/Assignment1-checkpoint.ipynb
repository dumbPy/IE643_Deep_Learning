# %%
import numpy as np
import random
from numpy.linalg import norm
import matplotlib.pyplot as plt

# %%
sample_pos=np.random.multivariate_normal(mean=[1]*100,
                                         cov=0.5*np.identity(100), 
                                         size=500)
sample_neg=np.random.multivariate_normal(mean=[-0.4]*100,
                                         cov=0.75*np.identity(100),
                                         size=500)

# %%
sample_neg.shape[0]
# Out:
# 500

# %%
# Out:
# 1.0019561429698687

# %%
#merge the positive and negative data into list of (vector,label) tuples
data=[(sample_pos[row],1) for row in range(sample_pos.shape[0])]+ \
     [(sample_neg[row],0) for row in range(sample_neg.shape[0])]

# %%
random.shuffle(data) #shuffles data inplace

# %% [markdown]
# ### Projection Algorithm
# for any given weight vector $w^t \in \mathbb{R}^{100}$, it's projection on the closed set $C =\{w \in \mathbb{R}^{100} : ||w||_2\leq1\}$
#
# $$\Pi_c[w^t] = \begin{cases}
#                 w^t \quad & if \quad ||w^t||\leq 1 \\\\
#                 \frac{w^t}{||w^t||_2} \quad & otherwise
#                 \end{cases}$$

# %%
def projection(W): return W/norm(W) if norm(W)>1 else W

# %%
class Q1Model(object):
    def __init__(self, k, data, eta):
        self.k, self.data, self.eta=k, data, eta
        #Initial Weight Matrix by Xavier Initialization
        self.W=np.random.multivariate_normal(mean=[0]*100,
                                             cov=0.01*np.identity(100),
                                             size=1)
        self.bestWeight=self.W.copy()
        self.loss_history=[]
        self.accuracy_history=[]
        self.bestLoss=np.infty #Will be updated by next line
        self.forward_on_whole_data() #Calc Loss on initialized weights
        
    def calc_loss(self, i):
        """Calculate loss in current setting for given index of data"""
        y_actual=self.data[i][1]
        x=self.data[i][0]
        return max(0, self.k-y_actual*np.dot(self.W,x))
        
    def step(self, i): #i is index in data
        loss=self.calc_loss(i)
        if loss:
            x= self.data[i][0]
            y_actual=np.dot(self.W,x)
            gradient=y_actual*x                     #Gradient
            self.W=self.W-self.eta*gradient         #Weight Update
            self.W=projection(self.W)                         #Projection
        self.forward_on_whole_data()        #Update loss on new weights
            
    def forward_on_whole_data(self):
        """Calculates Loss on whole data using current weights"""
        totalLoss=sum([self.calc_loss(i) for i in range(len(data))])
        self.loss_history.append(totalLoss)
        if totalLoss<self.bestLoss: #update best weight
            self.bestLoss=totalLoss
            self.bestWeight=self.W.copy()
        accuracy=np.asarray([(np.dot(self.W, data[i][0]) >=0 and data[i][1])  or  #For Positive
                            (np.dot(self.W, data[i][0]) <0 and not data[i][1]) #For Negative
                             for i in range(len(data))])
        self.accuracy_history.append(sum(accuracy))
        
    def fit(self):
        for i in range(len(data)): self.step(i)
    
    def get_regret(self):
        """Returns Regret at each update"""
        return np.asarray(self.loss_history)-self.bestLoss
    def get_loss(self):      return np.asarray(self.loss_history)
    def get_accuracy(self) : return np.asarray(self.accuracy_history)

# %%
model=Q1Model(k=1, data=data, eta=1)

# %%
model.fit()

# %%
f, ((ax1,ax2),(ax3,ax4))=plt.subplots(2, 2, figsize=(15,10))
f.suptitle(f"Assgnment1-Q1 k={model.k} eta={model.eta}         (173190009)", fontsize=15)
ax1.plot(model.get_regret());              ax1.set_title("Regret per Round")
ax2.plot(model.get_regret().cumsum());     ax2.set_title("Cumulative Regret")
ax3.plot(model.get_loss());                ax3.set_title("Loss on complete dataset with w^t")
ax4.plot(model.get_accuracy());            ax4.set_title("Accuracy per Round")
plt.show()
f.savefig(f'Assignment1_173190009_Q1_k{model.k}_eta{model.eta}.png')

# %%
np.dot(model.W, data[4][0]), data[4][1]
# Out:
# (array([ 0.14030466]), 0)

# %%
W=model.bestWeight

# %%
W
# Out:
# array([[ 0.03569862,  0.09042417,  0.05274719,  0.01515762,  0.06834229,
#          0.0466634 ,  0.04796707,  0.17079484,  0.14666982,  0.03239975,
#          0.14472204,  0.09611673,  0.13598528,  0.21070165,  0.05483659,
#          0.09014889, -0.02310117,  0.08680221,  0.02698515,  0.10400157,
#          0.04018092,  0.1276435 ,  0.08680097,  0.11164027,  0.05480786,
#         -0.02110984,  0.08854698,  0.15008248,  0.10770364,  0.01047472,
#          0.037088  ,  0.07814955, -0.0034583 ,  0.06692243,  0.06851229,
#          0.04545428,  0.19843477, -0.00226336,  0.05526939,  0.04016104,
#          0.00060948,  0.10755822,  0.02331929,  0.03632668,  0.10553318,
#          0.10805602, -0.02994255,  0.11810634,  0.05950985, -0.02862178,
#          0.05296384,  0.15852005,  0.1358385 ,  0.13571781,  0.12417116,
#         -0.02064591,  0.03444583,  0.08533796,  0.04745071,  0.12732313,
#          0.17647522,  0.00069258,  0.04099452, -0.04305076,  0.18277943,
#          0.07203093,  0.01080885,  0.07270141,  0.09152927,  0.1253635 ,
#          0.05104796,  0.09255674,  0.0909172 ,  0.01627723, -0.03872569,
#          0.140244  ,  0.04164282,  0.07504026,  0.08300976,  0.19168494,
#          0.15050716, -0.06401573,  0.03118471,  0.11358465,  0.1570947 ,
#          0.02279897,  0.10759135,  0.26471599,  0.05899216,  0.14516485,
#          0.15628573,  0.14465862, -0.00082574,  0.00113086,  0.08927497,
#          0.14161045,  0.05744687,  0.07122804,  0.18543237,  0.103871  ]])
